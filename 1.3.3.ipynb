# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# bullet 1
# pros - shows obvious relationships through color coordination.
# cons - poorly represents values of the same number and hard to interpret when data is clumped

# %%
iris = sns.load_dataset("iris")
iris2 = pd.melt(sl, "species", var_name="measurement")
sns.swarmplot(x="measurement", y="value", hue="species", data=iris2)

# %% [markdown]
# bullet 2
# pros
# plot 1 - shows trends of data between categories that looks identical to the naked eye.
# plot 2 - compares data right obove the other categories
# plot 3 - shows that a linear regression model is appropriate
# cons
# plot 1 - none
# plot 2 - none
# plot 3 - shows nothing useful to analyze data

# %%
sns.lmplot(x='sepal_length', y='sepal_width', hue='species', data=iris)

# %%
sl = sns.boxplot(x='sepal_length', y = 'species', data=iris, color = 'blue')
sw = sns.boxplot(x='sepal_width', y = 'species', data=iris, color = 'red')

# %%
x = iris['sepal_width']
y = iris['sepal_length']
sns.residplot(x, y)

# %% [markdown]
# bullet 3
# pros - shows all variables in close quarters with obvious labels to help identify all relationships
# cons - unnecessarily shows every plot twice but on inverse by switching x and y axis

# %%
scatter = sns.pairplot(iris, hue="species")
